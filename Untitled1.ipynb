# %%
import pandas as pd

# Data for K-Means clustering
kmeans_data = {
    "Preprocessing": ["none", "none", "none", "normalize", "normalize", "normalize"],
    "Algorithm": ["kmeans"] * 6,
    "n_clusters": [3, 4, 5, 3, 4, 5],
    "Silhouette Score": [0.5528, 0.4981, 0.3679, 0.5048, 0.4451, 0.4448],
    "Calinski-Harabasz Index": [561.6278, 530.7658, 456.3983, 359.8451, 314.4730, 270.7506],
    "Davies-Bouldin Index": [0.6620, 0.7803, 0.9238, 0.7603, 0.9004, 0.9249]
}

# Data for Hierarchical clustering with errors
hierarchical_data = {
    "Preprocessing": ["none", "none", "none", "normalize", "normalize", "normalize"],
    "Algorithm": ["hierarchical"] * 6,
    "n_clusters": [3, 4, 5, 3, 4, 5],
    "Silhouette Score": ["Error"] * 6,
    "Calinski-Harabasz Index": ["Error"] * 6,
    "Davies-Bouldin Index": ["Error"] * 6
}

# Data for Mean-Shift clustering with errors
mean_shift_data = {
    "Preprocessing": ["none", "none", "none", "normalize", "normalize", "normalize"],
    "Algorithm": ["mean_shift"] * 6,
    "n_clusters": [3, 4, 5, 3, 4, 5],
    "Silhouette Score": ["Error"] * 6,
    "Calinski-Harabasz Index": ["Error"] * 6,
    "Davies-Bouldin Index": ["Error"] * 6
}

# Create DataFrames
kmeans_df = pd.DataFrame(kmeans_data)
hierarchical_df = pd.DataFrame(hierarchical_data)
mean_shift_df = pd.DataFrame(mean_shift_data)

# Display results
print("K-Means Clustering Results")
print(kmeans_df)

print("\nHierarchical Clustering Results")
print(hierarchical_df)

print("\nMean-Shift Clustering Results")
print(mean_shift_df)

# Optionally, save to CSV for further use
kmeans_df.to_csv("kmeans_results.csv", index=False)
hierarchical_df.to_csv("hierarchical_results.csv", index=False)
mean_shift_df.to_csv("mean_shift_results.csv", index=False)
# Out:
# K-Means Clustering Results
#   Preprocessing Algorithm  n_clusters  Silhouette Score  \
# 0          none    kmeans           3            0.5528
# 1          none    kmeans           4            0.4981
# 2          none    kmeans           5            0.3679
# 3     normalize    kmeans           3            0.5048
# 4     normalize    kmeans           4            0.4451
# 5     normalize    kmeans           5            0.4448
#
#    Calinski-Harabasz Index  Davies-Bouldin Index
# 0                 561.6278                0.6620
# 1                 530.7658                0.7803
# 2                 456.3983                0.9238
# 3                 359.8451                0.7603
# 4                 314.4730                0.9004
# 5                 270.7506                0.9249
#
# Hierarchical Clustering Results
#   Preprocessing     Algorithm  n_clusters Silhouette Score  \
# 0          none  hierarchical           3            Error
# ...
